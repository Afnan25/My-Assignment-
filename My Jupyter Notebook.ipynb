# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Afnan Khaled__ <br>
# I'm planning to be a Data Scientist

# %% [markdown]
# *I'm inerested in data science becouse it's the future science that will make a revolution in technology and life. Data is the oil of this century.*

# %% [markdown]
# ### This code will print a sentence and a simple operation:

# %%
print("Hellow Collegues, I'm Afnan")
1+1
# Out:
# Hellow Collegues, I'm Afnan
# 2

# %% [markdown]
# - This is a Bulletted list
# + The next item
#  ___
# ```Python
# print("Me")
# ```
# ---
#
# > ~~~Blocked Quote says:~~~ "No pain, no gain"
